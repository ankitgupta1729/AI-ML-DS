# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

# %% [markdown]
# This is the classic SMS Spam Collection dataset: a set of labeled text messages, some legitimate ("ham") and some spam, covering all kinds of everyday topics -- health, weather and so forth.

# %%
# Unfortunately this URL doesn't work directly with pd.read_csv
# !wget -nc https://lazyprogrammer.me/course_files/spam.csv
# Out:
# File ‘spam.csv’ already there; not retrieving.

# %%
#bad formatting!
# !head spam.csv
# Out:
# v1,v2,,,
# ham,"Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...",,,
# ham,Ok lar... Joking wif u oni...,,,
# spam,Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's,,,
# ham,U dun say so early hor... U c already then say...,,,
# ham,"Nah I don't think he goes to usf, he lives around here though",,,
# spam,"FreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, �1.50 to rcv",,,
# ham,Even my brother is not like to speak with me. They treat me like aids patent.,,,
# ham,As per your request 'Melle Melle (Oru Minnaminunginte Nurungu Vettam)' has been set as your callertune for all Callers. Press *9 to copy your friends Callertune,,,
# spam,WINNER!! As a valued network customer you have been selected to receivea �900 prize reward! To claim call 09061701461. Claim code KL341. Valid 12 hours only.,,,

# %%
df = pd.read_csv('spam.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
# drop unnecessary columns
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# rename columns to something better
df.columns = ['labels', 'data']

# %%
df.head()
# Out:
#   labels                                               data
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
# create binary labels
df['b_labels'] = df['labels'].map({'ham': 0, 'spam': 1})

# %% [markdown]
# Note: normally you'd want to use something like sklearn's LabelEncoder to automatically map string columns to be integers from zero up to K minus one, but let's keep it simple!

# %%
df_train, df_test = train_test_split(df, test_size=0.33)

# %%
df_train.shape, df_test.shape
# Out:
# ((3733, 3), (1839, 3))

# %%
# 0 = padding
idx = 1
word2idx = {'<PAD>': 0}

# %%
# you could always use gensim or spacy for tokenization,
# but let's keep it simple!
for i, row in df_train.iterrows():
  tokens = row['data'].lower().split() # simple tokenization
  for token in tokens:
    if token not in word2idx:
      word2idx[token] = idx
      idx += 1

# %%
word2idx
# Out:
# {'<PAD>': 0,
#  'can': 1,
#  'you': 2,
#  'use': 3,
#  'foreign': 4,
#  'stamps': 5,
#  'for': 6,
#  'whatever': 7,
#  'send': 8,
#  'them': 9,
#  'off': 10,
#  'for?': 11,
#  'prepare': 12,
#  'to': 13,
#  'be': 14,
#  'pleasured': 15,
#  ':)': 16,
#  'wamma': 17,
#  'get': 18,
#  'laid?want': 19,
#  'real': 20,
#  'doggin': 21,
#  'locations': 22,
#  'sent': 23,
#  'direct': 24,
#  'your': 25,
#  'mobile?': 26,
#  'join': 27,
#  'the': 28,
#  'uks': 29,
#  'largest': 30,
#  'dogging': 31,
#  'network.': 32,
#  'txt': 33,
#  'dogs': 34,
#  '69696': 35,
#  'now!nyt.': 36,
#  'ec2a.': 37,
#  '3lp': 38,
#  'å£1.50/msg.': 39,
#  'huh': 40,
#  'but': 41,
#  'i': 42,
#  'cant': 43,
#  'go': 44,
#  '2': 45,
#  'ur': 46,
#  'house': 47,
#  'empty': 48,
#  'handed': 49,
#  'right?': 50,
#  'as': 51,
#  'a': 52,
#  'valued': 53,
#  'customer,': 54,
#  'am': 55,
#  'pleased': 56,
#  'advise': 57,
#  'that': 58,
#  'following': 59,
#  'recent': 60,
#  'review': 61,
#  'of': 62,
#  'mob': 63,
#  'no.': 64,
#  'are': 65,
#  'awarded': 66,
#  'with': 67,
#  'å£1500': 68,
#  'bonus': 69,
#  'prize,': 70,
#  'call': 71,
#  '09066364589': 72,
#  'gain': 73,
#  'rights': 74,
#  'wife.dont': 75,
#  'demand': 76,
#  'it.i': 77,
#  'trying': 78,
#  'husband': 79,
#  'too.lets': 80,
#  'see': 81,
#  'ok': 82,
#  'lor.': 83,
#  'ned': 84,
#  'toa': 85,
#  'payoh': 86,
#  '4': 87,
#  'while': 88,
#  'return': 89,
#  'smth': 90,
#  'u': 91,
#  'wan': 92,
#  'me': 93,
#  'there': 94,
#  'or': 95,
#  'wat?': 96,
#  '&lt;decimal&gt;': 97,
#  'm': 98,
#  'its': 99,
#  'not': 100,
#  'common': 101,
#  'car': 102,
#  'here': 103,
#  'so': 104,
#  'better': 105,
#  'buy': 106,
#  'from': 107,
#  'china': 108,
#  'asia.': 109,
#  'if': 110,
#  'find': 111,
#  'it': 112,
#  'less': 113,
#  'expensive.': 114,
#  'i.ll': 115,
#  'holla': 116,
#  'jesus': 117,
#  'armand': 118,
#  'really': 119,
#  'is': 120,
#  'tell': 121,
#  'everybody': 122,
#  'he': 123,
#  "i'm": 124,
#  'coming': 125,
#  'over,': 126,
#  'do': 127,
#  'want': 128,
#  'meet': 129,
#  'after': 130,
#  'lunch': 131,
#  'la...': 132,
#  "that's": 133,
#  'cool': 134,
#  "he'll": 135,
#  'all': 136,
#  'night,': 137,
#  'lemme': 138,
#  'know': 139,
#  'when': 140,
#  "you're": 141,
#  'around': 142,
#  'means': 143,
#  'could': 144,
#  'keep': 145,
#  'words.': 146,
#  'reply': 147,
#  'name': 148,
#  'and': 149,
#  'address': 150,
#  'will': 151,
#  'receive': 152,
#  'by': 153,
#  'post': 154,
#  'weeks': 155,
#  'completely': 156,
#  'free': 157,
#  'accommodation': 158,
#  'at': 159,
#  'various': 160,
#  'global': 161,
#  'www.phb1.com': 162,
#  'ph:08700435505150p': 163,
#  "he's": 164,
#  'an': 165,
#  'adult': 166,
#  'would': 167,
#  'learn': 168,
#  'experience.': 169,
#  "there's": 170,
#  'no': 171,
#  'danger.': 172,
#  'just': 173,
#  'dont': 174,
#  'like': 175,
#  'peeps': 176,
#  'using': 177,
#  'drugs': 178,
#  'they': 179,
#  'need.': 180,
#  'comment': 181,
#  'garbage': 182,
#  'bags,': 183,
#  'eggs,': 184,
#  'jam,': 185,
#  'bread,': 186,
#  'hannaford': 187,
#  'wheat': 188,
#  'chex': 189,
#  'per': 190,
#  'request': 191,
#  "'melle": 192,
#  'melle': 193,
#  '(oru': 194,
#  'minnaminunginte': 195,
#  'nurungu': 196,
#  "vettam)'": 197,
#  'has': 198,
#  'been': 199,
#  'set': 200,
#  'callertune': 201,
#  'callers.': 202,
#  'press': 203,
#  '*9': 204,
#  'copy': 205,
#  'friends': 206,
#  'two': 207,
#  'teams': 208,
#  'waiting': 209,
#  'some': 210,
#  'players': 211,
#  'this': 212,
#  'pen': 213,
#  'thing': 214,
#  'beyond': 215,
#  'joke.': 216,
#  'wont': 217,
#  'biro': 218,
#  'do?': 219,
#  "don't": 220,
#  'masters': 221,
#  "can't": 222,
#  'ever': 223,
#  'again!': 224,
#  'hey': 225,
#  'whats': 226,
#  'plan': 227,
#  'sat?': 228,
#  'pass': 229,
#  'dis': 230,
#  'contacts': 231,
#  'n': 232,
#  'wat': 233,
#  'get!': 234,
#  "red;i'm": 235,
#  'in': 236,
#  'luv': 237,
#  'wid': 238,
#  'u.': 239,
#  'blue;u': 240,
#  'put': 241,
#  'smile': 242,
#  'on': 243,
#  'my': 244,
#  'face.': 245,
#  'purple;u': 246,
#  'r': 247,
#  'realy': 248,
#  'hot.': 249,
#  'pink;u': 250,
#  'swt.': 251,
#  'orange;i': 252,
#  'thnk': 253,
#  'lyk': 254,
#  'green;i': 255,
#  'wana': 256,
#  'out': 257,
#  'yelow;i': 258,
#  'wnt': 259,
#  'bck.': 260,
#  "black;i'm": 261,
#  'jealous': 262,
#  'brown;i': 263,
#  'miss': 264,
#  'nw': 265,
#  'plz': 266,
#  'giv': 267,
#  'one': 268,
#  'color': 269,
#  'tho': 270,
#  'sucks.': 271,
#  'even': 272,
#  'cook': 273,
#  'whole': 274,
#  'electricity': 275,
#  'out.': 276,
#  'hungry.': 277,
#  'oh': 278,
#  'shut': 279,
#  'it.': 280,
#  'omg': 281,
#  'yesterday': 282,
#  'had': 283,
#  'dream': 284,
#  'kids': 285,
#  'both': 286,
#  'boys.': 287,
#  'was': 288,
#  'pissed.': 289,
#  'only': 290,
#  'about': 291,
#  'being': 292,
#  'told': 293,
#  'mark': 294,
#  'changing': 295,
#  'diapers': 296,
#  'cause': 297,
#  'getting': 298,
#  'owed': 299,
#  'height': 300,
#  'recycling:': 301,
#  'read': 302,
#  'twice-': 303,
#  'people': 304,
#  'spend': 305,
#  'time': 306,
#  'earning': 307,
#  'money': 308,
#  'same': 309,
#  'spent': 310,
#  'spending': 311,
#  'time!;-)': 312,
#  'good': 313,
#  'morning..': 314,
#  'smiling:-)': 315,
#  'congrats!': 316,
#  'nokia': 317,
#  '3650': 318,
#  'video': 319,
#  'camera': 320,
#  'phone': 321,
#  '09066382422': 322,
#  'calls': 323,
#  'cost': 324,
#  '150ppm': 325,
#  'ave': 326,
#  '3mins': 327,
#  'vary': 328,
#  'mobiles': 329,
#  '16+': 330,
#  'close': 331,
#  '300603': 332,
#  'bcm4284': 333,
#  'ldn': 334,
#  'wc1n3xx': 335,
#  'scores': 336,
#  'sophas': 337,
#  'secondary': 338,
#  'application': 339,
#  'few': 340,
#  'schools.': 341,
#  'think': 342,
#  'thinking': 343,
#  'applying,': 344,
#  'research': 345,
#  'also.': 346,
#  'contact': 347,
#  'joke': 348,
#  'ogunrinde,': 349,
#  'her': 350,
#  'school': 351,
#  'expensive': 352,
#  'ones': 353,
#  'sad': 354,
#  'story': 355,
#  'man': 356,
#  '-': 357,
#  'last': 358,
#  'week': 359,
#  "b'day.": 360,
#  'wife': 361,
#  "did'nt": 362,
#  'wish': 363,
#  'me.': 364,
#  'parents': 365,
#  'forgot': 366,
#  'did': 367,
#  '.': 368,
#  'went': 369,
#  'work.': 370,
#  'colleagues': 371,
#  'wish.': 372,
#  'entered': 373,
#  'cabin': 374,
#  'pa': 375,
#  'said,': 376,
#  "''": 377,
#  'happy': 378,
#  "b'day": 379,
#  'boss': 380,
#  "!!''.": 381,
#  'felt': 382,
#  'special.': 383,
#  'she': 384,
#  'askd': 385,
#  'lunch.': 386,
#  'invited': 387,
#  'apartment.': 388,
#  'we': 389,
#  'there.': 390,
#  "said,''": 391,
#  'mind': 392,
#  'into': 393,
#  'bedroom': 394,
#  'minute': 395,
#  '?': 396,
#  "''ok'',": 397,
#  'sed': 398,
#  'sexy': 399,
#  'mood.': 400,
#  'came': 401,
#  '5': 402,
#  'minuts': 403,
#  'latr': 404,
#  'cake...n': 405,
#  'wife,': 406,
#  'parents,': 407,
#  'kidz,': 408,
#  'colleagues.': 409,
#  'screaming..': 410,
#  'surprise': 411,
#  '!!': 412,
#  'sofa..': 413,
#  '...': 414,
#  '.....': 415,
#  "'": 416,
#  'naked...!': 417,
#  'meeting': 418,
#  'ì_': 419,
#  'rite': 420,
#  'then': 421,
#  "i'll": 422,
#  'home': 423,
#  'dun': 424,
#  'feel': 425,
#  'comin': 426,
#  "it's": 427,
#  'ok.': 428,
#  'fri': 429,
#  'ah...': 430,
#  'okie': 431,
#  'lor,goin': 432,
#  'drivin': 433,
#  'den': 434,
#  'shoppin': 435,
#  'tt...': 436,
#  'thanx': 437,
#  'lot...': 438,
#  'sorry,': 439,
#  'guess': 440,
#  'whenever': 441,
#  'hold': 442,
#  'connections,': 443,
#  'maybe': 444,
#  'hour': 445,
#  'two?': 446,
#  'text': 447,
#  'who': 448,
#  'night': 449,
#  'phasing': 450,
#  'fourth': 451,
#  'dimension': 452,
#  'normally': 453,
#  'drink': 454,
#  'more': 455,
#  'water': 456,
#  'daily:)': 457,
#  'old': 458,
#  'orchard': 459,
#  'near': 460,
#  'univ.': 461,
#  'how': 462,
#  'you?': 463,
#  'free,': 464,
#  'what': 465,
#  'happen': 466,
#  'truth': 467,
#  'ffffffffff.': 468,
#  'alright': 469,
#  'way': 470,
#  'up': 471,
#  'sooner?': 472,
#  'wn': 473,
#  'hurt': 474,
#  'd': 475,
#  'prsn': 476,
#  's': 477,
#  'u,': 478,
#  'fight': 479,
#  'wit': 480,
#  'dem.': 481,
#  'coz': 482,
#  'somtimes': 483,
#  'saves': 484,
#  'relation': 485,
#  'bt': 486,
#  'quiet': 487,
#  'leaves': 488,
#  'nothin': 489,
#  'relation..': 490,
#  'gud': 491,
#  'eveb-)': 492,
#  'escape': 493,
#  'theatre': 494,
#  'now.': 495,
#  'going': 496,
#  'watch': 497,
#  'kavalan': 498,
#  'minutes': 499,
#  'cock!': 500,
#  "hubby's": 501,
#  'away,': 502,
#  'need': 503,
#  'satisfy': 504,
#  '89938': 505,
#  'strings': 506,
#  'action.': 507,
#  '(txt': 508,
#  'stop': 509,
#  'end,': 510,
#  'rec': 511,
#  'å£1.50ea.': 512,
#  'otbox': 513,
#  '731': 514,
#  'la1': 515,
#  '7ws.': 516,
#  ')': 517,
#  'great.': 518,
#  'church': 519,
#  'now,': 520,
#  'alright,': 521,
#  'bit': 522,
#  'sell': 523,
#  "we'll": 524,
#  'have': 525,
#  'tons': 526,
#  'coins.': 527,
#  'our': 528,
#  'coins': 529,
#  'someone': 530,
#  'thru': 531,
#  'paypal.': 532,
#  'voila!': 533,
#  'back': 534,
#  'life': 535,
#  'pockets:)': 536,
#  'show': 537,
#  'colours!': 538,
#  'euro': 539,
#  '2004': 540,
#  '2-4-1': 541,
#  'offer!': 542,
#  'england': 543,
#  'flag': 544,
#  '&': 545,
#  '3lions': 546,
#  'tone': 547,
#  'phone!': 548,
#  'click': 549,
#  'service': 550,
#  'message': 551,
#  'info!': 552,
#  'arms': 553,
#  'fine,': 554,
#  "how's": 555,
#  'cardiff': 556,
#  'uni?': 557,
#  'evening!': 558,
#  'roger.': 559,
#  "i'd": 560,
#  'say': 561,
#  'sign': 562,
#  'but,': 563,
#  'well,': 564,
#  'track': 565,
#  'record': 566,
#  'reading': 567,
#  'women': 568,
#  'smoking': 569,
#  'help': 570,
#  'us': 571,
#  'work': 572,
#  'through': 573,
#  'difficult': 574,
#  'dear': 575,
#  'voucher': 576,
#  'holder,': 577,
#  'claim': 578,
#  'offer,': 579,
#  'pc': 580,
#  'please': 581,
#  'http://www.e-tlp.co.uk/reward.': 582,
#  'ts&cs': 583,
#  'apply.': 584,
#  'seeing': 585,
#  'missed': 586,
#  'brother.': 587,
#  'gr8': 588,
#  'day.': 589,
#  'ok..': 590,
#  'congrats': 591,
#  '!': 592,
#  'treat': 593,
#  'pending.i': 594,
#  'mail': 595,
#  'days.will': 596,
#  'once': 597,
#  'thru.respect': 598,
#  'mother': 599,
#  'home.check': 600,
#  'mails.': 601,
#  'sis': 602,
#  'how?': 603,
#  'taka': 604,
#  'come': 605,
#  'look': 606,
#  'us?': 607,
#  'mrng': 608,
#  'nice': 609,
#  'day': 610,
#  '750': 611,
#  'anytime': 612,
#  'any': 613,
#  'network': 614,
#  'mins': 615,
#  '150': 616,
#  'new': 617,
#  'five': 618,
#  'pounds': 619,
#  '08000776320': 620,
#  'now': 621,
#  'delivery': 622,
#  'tomorrow': 623,
#  '....photoshop': 624,
#  'makes': 625,
#  'computer': 626,
#  'down.': 627,
#  "you've": 628,
#  'won': 629,
#  'tkts': 630,
#  'euro2004': 631,
#  'cup': 632,
#  'final': 633,
#  'å£800': 634,
#  'cash,': 635,
#  'collect': 636,
#  '09058099801': 637,
#  'b4190604,': 638,
#  'pobox': 639,
#  '7876150ppm': 640,
#  'sorry': 641,
#  'mates': 642,
#  'didnt': 643,
#  'write': 644,
#  'love': 645,
#  'kate': 646,
#  'wow.': 647,
#  'right!': 648,
#  "didn't": 649,
#  'mean': 650,
#  'that.': 651,
#  'gave': 652,
#  'boston': 653,
#  'men': 654,
#  'changed': 655,
#  'search': 656,
#  'location': 657,
#  'nyc,': 658,
#  'something': 659,
#  'changed.': 660,
#  'cuz': 661,
#  'signin': 662,
#  'page': 663,
#  'still': 664,
#  'says': 665,
#  'boston.': 666,
#  'haha': 667,
#  'too': 668,
#  'ugh': 669,
#  'wanna': 670,
#  'bed.': 671,
#  'warm.': 672,
#  'okie...': 673,
#  'thank': 674,
#  'princess!': 675,
#  'juicy': 676,
#  'booty...': 677,
#  'somebody': 678,
#  'website': 679,
#  'where': 680,
#  'play': 681,
#  'em': 682,
#  'eve': 683,
#  'online': 684,
#  'spacebucks': 685,
#  'job': 686,
#  'profile': 687,
#  'seems': 688,
#  'bpo..': 689,
#  'thanks': 690,
#  'temales': 691,
#  'wonderful.': 692,
#  'thank.': 693,
#  'great': 694,
#  'week.': 695,
#  'opinion': 696,
#  'me?': 697,
#  '1.': 698,
#  'over': 699,
#  '2.': 700,
#  'jada': 701,
#  '3.': 702,
#  'kusruthi': 703,
#  '4.': 704,
#  'lovable': 705,
#  '5.': 706,
#  'silent': 707,
#  '6.': 708,
#  'spl': 709,
#  'character': 710,
#  '7.': 711,
#  'matured': 712,
#  '8.': 713,
#  'stylish': 714,
#  '9.': 715,
#  'simple': 716,
#  'pls': 717,
#  'reply..': 718,
#  'sorry,in': 719,
#  'later': 720,
#  '10': 721,
#  'min': 722,
#  'k...': 723,
#  'lol': 724,
#  'remember': 725,
#  'til': 726,
#  'nite': 727,
#  's:)but': 728,
#  'luck.2': 729,
#  'catches': 730,
#  'down:)': 731,
#  'bahamas!': 732,
#  'callfreefone': 733,
#  '08081560665': 734,
#  'speak': 735,
#  'live': 736,
#  'operator': 737,
#  'either': 738,
#  'bahamas': 739,
#  'cruise': 740,
#  'ofå£2000': 741,
#  'cash': 742,
#  '18+only.': 743,
#  'opt': 744,
#  'x': 745,
#  '07786200117': 746,
#  'haf': 747,
#  'da': 748,
#  'canteen': 749,
#  'dump': 750,
#  'heap.': 751,
#  'mom': 752,
#  'decided': 753,
#  'lowes.': 754,
#  'boring.': 755,
#  'baby!': 756,
#  'promise': 757,
#  'well!': 758,
#  'bet': 759,
#  'take': 760,
#  'care': 761,
#  'me...': 762,
#  'dunno': 763,
#  'next': 764,
#  'aft': 765,
#  '6': 766,
#  '850.': 767,
#  'got': 768,
#  '650.': 769,
#  'ello': 770,
#  'babe': 771,
#  'ok?': 772,
#  'dial': 773,
#  'juz': 774,
#  'open': 775,
#  'browser': 776,
#  'surf...': 777,
#  'lmao': 778,
#  'needing': 779,
#  'hair': 780,
#  'anymore.': 781,
#  '\\thinking': 782,
#  ';)': 783,
#  'x\\""': 784,
#  'make': 785,
#  'tonight': 786,
#  'cool,': 787,
#  'latest': 788,
#  'handset?': 789,
#  'mins?': 790,
#  'half': 791,
#  'price': 792,
#  'line': 793,
#  'rental?': 794,
#  '08000930705': 795,
#  'jos': 796,
#  'ask': 797,
#  'up?': 798,
#  'die...': 799,
#  'e': 800,
#  'toot': 801,
#  'fringe': 802,
#  'again...': 803,
#  'seen': 804,
#  "who's": 805,
#  'holby?!': 806,
#  'alrite': 807,
#  'mobile': 808,
#  '3g': 809,
#  'videophones': 810,
#  'yours.': 811,
#  '09061744553': 812,
#  'now!': 813,
#  'videochat': 814,
#  'mates,': 815,
#  'java': 816,
#  'games,': 817,
#  'dload': 818,
#  'polyh': 819,
#  'music,': 820,
#  'noline': 821,
#  'rentl.': 822,
#  'bx420.': 823,
#  'ip4.': 824,
#  '5we.': 825,
#  '150pm': 826,
#  'another': 827,
#  'month.': 828,
#  'chocolate': 829,
#  'weed': 830,
#  'alcohol.': 831,
#  'id': 832,
#  'onluy': 833,
#  'matters': 834,
#  'offcampus': 835,
#  'babe!': 836,
#  'fucking': 837,
#  'know?': 838,
#  'fuck': 839,
#  'hear': 840,
#  'voice.': 841,
#  'crave': 842,
#  'enough.': 843,
#  'adore': 844,
#  'you,': 845,
#  'ahmad': 846,
#  '*kisses*': 847,
#  'science': 848,
#  'tells': 849,
#  'melt': 850,
#  'under': 851,
#  'sunlight.': 852,
#  'walk': 853,
#  'bcoz,i': 854,
#  'loss': 855,
#  'sweet': 856,
#  'friend.': 857,
#  'watching': 858,
#  'tv': 859,
#  'sounds': 860,
#  'testing': 861,
#  'sayy': 862,
#  'yo!': 863,
#  'howz': 864,
#  'u?': 865,
#  'girls': 866,
#  'never': 867,
#  'rang': 868,
#  'india.': 869,
#  'l': 870,
#  'beautiful': 871,
#  'against': 872,
#  'gravity..': 873,
#  'carefully:': 874,
#  '\\our': 875,
#  'heart': 876,
#  'feels': 877,
#  'light': 878,
#  'it..': 879,
#  'very': 880,
#  'heavy': 881,
#  'it..\\"': 882,
#  'goodmorning"': 883,
#  '\\its': 884,
#  'luck': 885,
#  'someone.': 886,
#  'fortune': 887,
#  'loves': 888,
#  'tyler': 889,
#  "we're": 890,
#  'gonna': 891,
#  'him': 892,
#  'drop': 893,
#  'his': 894,
#  'place': 895,
#  'tonight.': 896,
#  'total': 897,
#  'order': 898,
#  'quarter,': 899,
#  'enough?': 900,
#  'care.': 901,
#  'understand.': 902,
#  'poly': 903,
#  'tones': 904,
#  'mobs': 905,
#  '2u': 906,
#  'rply': 907,
#  'title': 908,
#  '8007': 909,
#  'eg': 910,
#  'breathe1': 911,
#  'titles:': 912,
#  'crazyin,': 913,
#  'sleepingwith,': 914,
#  'finest,': 915,
#  'ymca': 916,
#  ':getzed.co.uk': 917,
#  'pobox365o4w45wq': 918,
#  '300p': 919,
#  'hi': 920,
#  'dude': 921,
#  'hw': 922,
#  'mising': 923,
#  'today': 924,
#  'win': 925,
#  'å£100': 926,
#  'music': 927,
#  'gift': 928,
#  'vouchers': 929,
#  'every': 930,
#  'starting': 931,
#  'word': 932,
#  'draw': 933,
#  '87066': 934,
#  'tscs': 935,
#  'www.idew.com': 936,
#  'skillgame,': 937,
#  '1winaweek,': 938,
#  'age16.': 939,
#  '150ppermesssubscription': 940,
#  'aight,': 941,
#  'chillin': 942,
#  "friend's": 943,
#  'room': 944,
#  'email': 945,
#  'alertfrom:': 946,
#  'jeri': 947,
#  'stewartsize:': 948,
#  '2kbsubject:': 949,
#  'low-cost': 950,
#  'prescripiton': 951,
#  'drvgsto': 952,
#  'listen': 953,
#  '123': 954,
#  'darlin!im': 955,
#  'thanx.': 956,
#  'bday': 957,
#  'drinks': 958,
#  'nite.': 959,
#  '2morrow': 960,
#  'off!': 961,
#  'c': 962,
#  'soon.xxx': 963,
#  'enjoy': 964,
#  'role': 965,
#  'playing': 966,
#  'much?': 967,
#  'k.i': 968,
#  '&lt;#&gt;': 969,
#  'min:)': 970,
#  'yo': 971,
#  'im': 972,
#  'right': 973,
#  'logging': 974,
#  'desert.': 975,
#  'geoenvironmental': 976,
#  'implications.': 977,
#  'ìï': 978,
#  'lessons?': 979,
#  'sch?': 980,
#  'elaine,': 981,
#  "today's": 982,
#  'on?': 983,
#  'leave': 984,
#  'class': 985,
#  ':-(': 986,
#  'hope': 987,
#  'sleep,': 988,
#  'called': 989,
#  'yet': 990,
#  'chikku..wat': 991,
#  'abt': 992,
#  'size': 993,
#  'elephant': 994,
#  'tablets': 995,
#  'shove': 996,
#  'um': 997,
#  'ass!!': 998,
#  'sry': 999,
#  ...}

# %%
len(word2idx)
# Out:
# 10755

# %%
# convert data into word indices
# note: could have done this on the fly earlier
train_sentences_as_int = []
for i, row in df_train.iterrows():
  tokens = row['data'].lower().split()
  sentence_as_int = [word2idx[token] for token in tokens]
  train_sentences_as_int.append(sentence_as_int)

# %%
test_sentences_as_int = []
for i, row in df_test.iterrows():
  tokens = row['data'].lower().split()
  sentence_as_int = [word2idx[token] for token in tokens if token in word2idx]
  test_sentences_as_int.append(sentence_as_int)

# %%
len(train_sentences_as_int), len(test_sentences_as_int)
# Out:
# (3733, 1839)

# %%
def data_generator(X, y, batch_size=32):
  X, y = shuffle(X, y)
  n_batches = int(np.ceil(len(y) / batch_size))
  for i in range(n_batches):
    end = min((i + 1) * batch_size, len(y))

    X_batch = X[i * batch_size:end]
    y_batch = y[i * batch_size:end]

    # pad X_batch to be N x T
    max_len = np.max([len(x) for x in X_batch])
    for j in range(len(X_batch)):
      x = X_batch[j]
      pad = [0] * (max_len - len(x))
      X_batch[j] = pad + x

    # convert to tensor
    X_batch = torch.from_numpy(np.array(X_batch)).long()
    y_batch = torch.from_numpy(np.array(y_batch)).long()

    yield X_batch, y_batch

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else ("cuda:0" if torch.cuda.is_available() else "cpu"))
print(device)
# Out:
# mps

# %%
# What is the shape of embedding output?
# N x T x D
embed = nn.Embedding(len(word2idx), 20)
for inputs, targets in data_generator(train_sentences_as_int, df_train.b_labels):
  out = embed(inputs)
  print("Input shape:", inputs.shape)
  print("Output shape:", out.shape)
  break
# Out:
# Input shape: torch.Size([32, 47])
# Output shape: torch.Size([32, 47, 20])

# %% [markdown]
# This brings us to our custom CNN model in the constructor, we create our embedding layer, a series of conv/pool layers, and a final dense layer.

# %%
# Define the model
class CNN(nn.Module):
  def __init__(self, n_vocab, embed_dim, n_outputs):
    super(CNN, self).__init__()
    self.V = n_vocab
    self.D = embed_dim
    self.K = n_outputs

    # if input is T words
    # then output is (T, D) matrix
    self.embed = nn.Embedding(self.V, self.D)

    # conv layers
    self.conv1 = nn.Conv1d(self.D, 32, 3, padding=1)
    self.pool1 = nn.MaxPool1d(2)
    self.conv2 = nn.Conv1d(32, 64, 3, padding=1)
    self.pool2 = nn.MaxPool1d(2)
    self.conv3 = nn.Conv1d(64, 128, 3, padding=1)

    self.fc = nn.Linear(128, self.K)

  def forward(self, X):
    # embedding layer
    # turns word indexes into word vectors
    out = self.embed(X)

    # note: output of embedding is always
    # (N, T, D)
    # conv1d expects
    # (N, D, T)

    # conv layers
    out = out.permute(0, 2, 1)
    out = self.conv1(out)
    out = F.relu(out)
    out = self.pool1(out)
    out = self.conv2(out)
    out = F.relu(out)
    out = self.pool2(out)
    out = self.conv3(out)
    out = F.relu(out)

    # change it back
    out = out.permute(0, 2, 1)

    # max pool
    out, _ = torch.max(out, 1)

    # final dense layer
    out = self.fc(out)
    return out

# %%
model = CNN(len(word2idx), 20, 1)
model.to(device)
# Out:
# CNN(
#   (embed): Embedding(10755, 20)
#   (conv1): Conv1d(20, 32, kernel_size=(3,), stride=(1,), padding=(1,))
#   (pool1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(32, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#   (pool2): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#   (fc): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
# Loss and optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters())

# %%
train_gen = lambda: data_generator(train_sentences_as_int, df_train.b_labels)
test_gen = lambda: data_generator(test_sentences_as_int, df_test.b_labels)

# %%
# A function to encapsulate the training loop
def batch_gd(model, criterion, optimizer, epochs):
  train_losses = np.zeros(epochs)
  test_losses = np.zeros(epochs)

  for it in range(epochs):
    t0 = datetime.now()
    train_loss = []
    for inputs, targets in train_gen():
      targets = targets.view(-1, 1).float()
      # move data to GPU
      inputs, targets = inputs.to(device), targets.to(device)

      # zero the parameter gradients
      optimizer.zero_grad()

      # Forward pass
      outputs = model(inputs)
      loss = criterion(outputs, targets)

      # Backward and optimize
      loss.backward()
      optimizer.step()

      train_loss.append(loss.item())

    # Get train loss and test loss
    train_loss = np.mean(train_loss)

    test_loss = []
    for inputs, targets in test_gen():
      targets = targets.view(-1, 1).float()
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      loss = criterion(outputs, targets)
      test_loss.append(loss.item())
    test_loss = np.mean(test_loss)

    # Save losses
    train_losses[it] = train_loss
    test_losses[it] = test_loss

    dt = datetime.now() - t0
    print(f'Epoch {it+1}/{epochs}, Train Loss: {train_loss:.4f}, \
      Test Loss: {test_loss:.4f}, Duration: {dt}')

  return train_losses, test_losses

# %%
train_losses, test_losses = batch_gd(
    model, criterion, optimizer, epochs=8)
# Out:
# Epoch 1/8, Train Loss: 0.4013,       Test Loss: 0.3366, Duration: 0:00:03.872363
# Epoch 2/8, Train Loss: 0.2703,       Test Loss: 0.1620, Duration: 0:00:00.586698
# Epoch 3/8, Train Loss: 0.1444,       Test Loss: 0.1219, Duration: 0:00:00.745094
# Epoch 4/8, Train Loss: 0.0976,       Test Loss: 0.1098, Duration: 0:00:00.536342
# Epoch 5/8, Train Loss: 0.0696,       Test Loss: 0.1056, Duration: 0:00:00.639240
# Epoch 6/8, Train Loss: 0.0480,       Test Loss: 0.1046, Duration: 0:00:00.660817
# Epoch 7/8, Train Loss: 0.0323,       Test Loss: 0.1124, Duration: 0:00:00.621219
# Epoch 8/8, Train Loss: 0.0252,       Test Loss: 0.1050, Duration: 0:00:00.653595

# %% [markdown]
# The next step is to plot the losses per iteration.

# %%
# Plot the train loss and test loss per iteration
plt.plot(train_losses, label='train loss')
plt.plot(test_losses, label='test loss')
plt.legend()
plt.show()

# %% [markdown]
# The next step is to calculate the accuracy.

# %%
# Accuracy

n_correct = 0.
n_total = 0.
for inputs, targets in train_gen():
  targets = targets.view(-1, 1).float()
  inputs, targets = inputs.to(device), targets.to(device)

  # Forward pass
  outputs = model(inputs)

  # Get prediction
  predictions = (outputs > 0)

  # update counts
  n_correct += (predictions == targets).sum().item()
  n_total += targets.shape[0]

train_acc = n_correct / n_total


n_correct = 0.
n_total = 0.
for inputs, targets in test_gen():
  targets = targets.view(-1, 1).float()
  inputs, targets = inputs.to(device), targets.to(device)

  # Forward pass
  outputs = model(inputs)

  # Get prediction
  predictions = (outputs > 0)

  # update counts
  n_correct += (predictions == targets).sum().item()
  n_total += targets.shape[0]

test_acc = n_correct / n_total
print(f"Train acc: {train_acc:.4f}, Test acc: {test_acc:.4f}")
# Out:
# Train acc: 0.9968, Test acc: 0.9728
