# %% [markdown]
# Installation and Setup on MacOS: https://www.youtube.com/watch?v=WxWRXNna1Qw&t=63s&pp=ygUfaW5zdGFsbCBweXNwYXJrIG9uIG1hY29zIDE1LjcuMw%3D%3D

# %%
# Set the PySpark Environment Variables

# %%
import os
os.environ['SPARK_HOME']="/Users/ankit/Documents/PySpark/Spark"

# %%
os.environ['PYSPARK_DRIVER_PYTHON']='jupyter'
os.environ['PYSPARK_DRIVER_PYTHON_OPTS']='lab'
os.environ['PYSPARK_PYTHON']='python'

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder \
        .appName("PySpark-Get-Started") \
        .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/12/18 02:21:38 WARN Utils: Your hostname, MacBook-Air.local, resolves to a loopback address: 127.0.0.1; using 10.66.203.165 instead (on interface en0)
# 25/12/18 02:21:38 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/18 02:21:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
data = [("Alice",25),("Bob",30),("Charlie",35)]
df = spark.createDataFrame(data,["Name","Age"])

# %%
df.show()
# Out:
# +-------+---+
# |   Name|Age|
# +-------+---+
# |  Alice| 25|
# |    Bob| 30|
# |Charlie| 35|
# +-------+---+
