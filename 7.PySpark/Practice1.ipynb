# %%
from pyspark import SparkConf, SparkContext

# %%
conf = SparkConf()
conf.setMaster("local")
conf.setAppName('spark-basic')
sc = SparkContext(conf=conf)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/29 21:38:16 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
import numpy as np
def mod(x):
    return (x,np.mod(x,2))
rdd = sc.parallelize(range(1000)).map(mod).take(10)
print(rdd)
# Out:
# [(0, 0), (1, 1), (2, 0), (3, 1), (4, 0), (5, 1), (6, 0), (7, 1), (8, 0), (9, 1)]

# %%
conf = SparkConf().setAppName("MyFirstApp").setMaster("local")
sc = SparkContext(conf=conf)
print("Hello, Spark!")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 conf = SparkConf().setAppName("MyFirstApp").setMaster("local")
# ----> 2 sc = SparkContext(conf=conf)
#       3 print("Hello, Spark!")
#
# File ~/Workspace/Projects/ankit-github/AI-ML-DS/.venv/lib/python3.11/site-packages/pyspark/core/context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File ~/Workspace/Projects/ankit-github/AI-ML-DS/.venv/lib/python3.11/site-packages/pyspark/core/context.py:476, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     473     callsite = SparkContext._active_spark_context._callsite
#     475     # Raise error if there is already a running Spark context
# --> 476     raise ValueError(
#     477         "Cannot run multiple SparkContexts at once; "
#     478         "existing SparkContext(app=%s, master=%s)"
#     479         " created by %s at %s:%s "
#     480         % (
#     481             currentAppName,
#     482             currentMaster,
#     483             callsite.function,
#     484             callsite.file,
#     485             callsite.linenum,
#     486         )
#     487     )
#     488 else:
#     489     SparkContext._active_spark_context = instance
#
# ValueError: Cannot run multiple SparkContexts at once; existing SparkContext(app=spark-basic, master=local) created by __init__ at /var/folders/8t/4ttt_tc53hs994xcrmjg2p880000gn/T/ipykernel_14127/3534141817.py:4

# %%
sc.stop()

# %%
conf = SparkConf().setAppName("MyFirstApp").setMaster("local")
sc = SparkContext(conf=conf)
print("Hello, Spark!")
# Out:
# Hello, Spark!

# %% [markdown]
# getOrCreate() reuses existing SparkContext instead of creating a new one.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("spark-basic") \
    .master("local") \
    .getOrCreate()

sc = spark.sparkContext
