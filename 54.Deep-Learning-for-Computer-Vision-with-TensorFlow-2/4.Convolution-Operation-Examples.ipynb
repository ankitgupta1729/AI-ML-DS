# %%
# In [1]:
from scipy.signal import convolve2d
from skimage.data import coffee
from skimage import color
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# In [2]:
plt.imshow(coffee())
plt.show()

# %%
# In [ ]:
img = color.rgb2gray(coffee())
plt.imshow(img, cmap=plt.cm.gray)
plt.axis('off')
plt.show()
# Out:
# /Users/ankit/Workspace/Projects/ankit-github/AI-ML-DS/54.Deep-Learning-for-Computer-Vision-with-TensorFlow-2/.venv/lib/python3.12/site-packages/skimage/color/colorconv.py:984: RuntimeWarning: divide by zero encountered in matmul
#   return rgb @ coeffs
# /Users/ankit/Workspace/Projects/ankit-github/AI-ML-DS/54.Deep-Learning-for-Computer-Vision-with-TensorFlow-2/.venv/lib/python3.12/site-packages/skimage/color/colorconv.py:984: RuntimeWarning: overflow encountered in matmul
#   return rgb @ coeffs
# /Users/ankit/Workspace/Projects/ankit-github/AI-ML-DS/54.Deep-Learning-for-Computer-Vision-with-TensorFlow-2/.venv/lib/python3.12/site-packages/skimage/color/colorconv.py:984: RuntimeWarning: invalid value encountered in matmul
#   return rgb @ coeffs

# %%
# In [4]:
import numpy as np
kernel_edge_detect1 = np.array([[1.,0.,-1.],
                                 [0.,0.,0.],
                                 [-1.,0.,1.]])

kernel_edge_detect2 = np.array([[0.,1.,0.],
                                 [1.,-4.,1.],
                                 [0.,1.,0.]])

kernel_edge_detect3 = np.array([[-1.,-1.,-1.],
                                 [-1.,8.,-1.],
                                 [-1.,-1.,-1.]])

kernel_sharpen = np.array([[0.,-1.,0.],
                            [-1.,5.,-1.],
                            [0.,-1.,0.]])

kernel_sharpen2 = np.array([[-1.,-1.,-1.],
                             [-1.,9.,-1.],
                             [-1.,-1.,-1.]])

kernel_blur = np.array([[1,1.,1.],
                         [1.,1.,1.],
                         [1.,1.,1.]])

# %%
# In [ ]:
img_edge1 = convolve2d(img, kernel_edge_detect1, 'valid')
plt.imshow(img_edge1, cmap=plt.cm.gray)
plt.axis('off')
plt.show()

# %%
# In [ ]:
img_edge2 = convolve2d(img, kernel_edge_detect2, 'valid')
plt.imshow(img_edge2, cmap=plt.cm.gray)
plt.axis('off')
plt.show()

# %%
# In [ ]:
img_edge3 = convolve2d(img, kernel_edge_detect3, 'valid')
plt.imshow(img_edge3, cmap=plt.cm.gray)
plt.axis('off')
plt.show()

# %%
# In [ ]:
img_sharpen = convolve2d(img, kernel_sharpen, 'valid')
plt.imshow(img_sharpen, cmap=plt.cm.gray)
plt.axis('off')
plt.show()

# %%
# In [ ]:
img_sharpen2 = convolve2d(img, kernel_sharpen2, 'valid')
plt.imshow(img_sharpen2, cmap=plt.cm.gray)
plt.axis('off')
plt.show()

# %%
# In [ ]:
img_blur = convolve2d(img, kernel_blur, 'valid')
plt.imshow(img_blur, cmap=plt.cm.gray)
plt.axis('off')
plt.show()
